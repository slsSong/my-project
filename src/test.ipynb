# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %%
print("오늘 점심메뉴 추천 받습니다")
# Out:
# 오늘 점심메뉴 추천 받습니다

# %%
# 샵하나는 큰제목
## 샵두개는 작은제목
### 샵세개는 더작은 제목
#### 샵네개는 더더작은제목
- 목록1
- 목록2
1.넘버는 넘버링1
2.넘버는 넘버링2
# Out:
#   Cell In[4], line 7
#     1.넘버는 넘버링1
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 샵하나는 큰제목
# ## 샵두개는 작은제목
# ### 샵세개는 더작은 제목
# #### 샵네개는 더더작은제목
# - 목록1
# - 목록2
#
# 1.넘버는 넘버링1
#
# 2.넘버는 넘버링2

# %%
print("셀2")
# Out:
# 셀2
